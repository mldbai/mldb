# %% [markdown]
# # Exploring Favourite Recipes
#
# [AllRecipes](http://allrecipes.com/) is a recipe website, where people can mark certain recipes as 'favourites'. A student named Jeremy Cohen [scraped some of this data for an excellent machine learning project](http://www.jeremymcohen.net/posts/taste/) and we'll use his dataset to demo how to do some unsupervised machine learning with MLDB.

# %% [markdown]
# The notebook cells below use `pymldb`'s `Connection` class to make [REST API](/doc/#builtin/WorkingWithRest.md.html) calls. You can check out the [Using `pymldb` Tutorial](/doc/nblink.html#_tutorials/Using pymldb Tutorial) for more details.

# %%
from pymldb import Connection
mldb = Connection()

# %% [markdown]
# The sequence of procedures below is based on the one explained in the [Mapping Reddit](/doc/nblink.html#_demos/Mapping Reddit) demo notebook.

# %%
mldb.v1.datasets("rcp_raw").put({
    "type": "text.csv.tabular",
    "params": {
        "headers": ["user_id", "recipe_id"],
        "dataFileUrl": "https://raw.githubusercontent.com/jmcohen/taste/master/data/favorites.csv"
    }
})

mldb.v1.procedures.post({
    "id": "rcp_import",
    "type": "transform",
    "params": {
        "inputDataset": "rcp_raw",
        "outputDataset": "recipes",
        "select": "pivot(recipe_id, 1) as *",
        "groupBy": "user_id", 
        "rowName": "user_id",
        "runOnCreation": True
    }
})

mldb.v1.procedures.post({
    "id": "rcp_svd",
    "type" : "svd.train",
    "params" : {
        "trainingDataset": "recipes",
        "columnOutputDataset" : "rcp_svd_embedding",
        "runOnCreation": True
    }
})

mldb.v1.procedures.post({
    "id" : "rcp_kmeans",
    "type" : "kmeans.train",
    "params" : {
        "trainingDataset" : "rcp_svd_embedding",
        "outputDataset" : "rcp_kmeans_clusters",
        "centroidsDataset" : "rcp_kmeans_centroids",
        "numClusters" : 20,
        "runOnCreation": True
    }
})

mldb.v1.procedures.post({
    "id": "rcp_tsne",
    "type" : "tsne.train",
    "params" : {
        "trainingDataset" : "rcp_svd_embedding",
        "rowOutputDataset" : "rcp_tsne_embedding",
        "runOnCreation": True
    }
})

mldb.v1.datasets("rcp_merged").put({
    "type": "merged",
    "params": {
        "datasets": [
            {"id": "rcp_svd_embedding"}, 
            {"id": "rcp_tsne_embedding"}, 
            {"id": "rcp_kmeans_clusters"}
        ]
    }
})
# Out:
# <Response [201]>

# %% [markdown]
# Let's load up the recipe names so we can see what we clustered.

# %%
import numpy as np
import pandas as pd
import urllib2 
names = []
for i, l in enumerate(urllib2.urlopen("https://raw.githubusercontent.com/jmcohen/taste/master/data/recipes.csv")):
    pieces = l.strip().split(",")
    names.append(",".join(pieces[1:]).replace("&#34;", '"').replace("'", "'"))

names = np.array(names)

def recipe_names(row_names):
    return names[ [int(x.split("|")[0]) for x in row_names] ]

# %% [markdown]
# Let's look a the closest recipes to each cluster centroid to try to get a sense of what the clusters mean.

# %%
centroids = mldb.query("select * from rcp_kmeans_centroids order by implicit_cast(rowName())")
import json
from IPython.display import display
rows = []
for x in json.loads(centroids.to_json(orient="records")):
    result = mldb.v1.datasets("rcp_svd_embedding").routes.neighbours.get(**x)
    rows.append(recipe_names(r[0] for r in result.json()))
pd.DataFrame(rows)
# Out:
#                                           0  \
# 0                A Good Easy Garlic Chicken
# 1                          American Lasagna
# 2             Chicken and Biscuit Casserole
# 3                     Cream Filled Cupcakes
# 4               Easy Spicy Roasted Potatoes
# 5             Super-Delicious Zuppa Toscana
# 6                Pesto Cheesy Chicken Rolls
# 7                          French Baguettes
# 8                        Shrimp Scampi Bake
# 9                      Chicken Tikka Masala
# 10       Taqueria Style Tacos - Carne Asada
# 11                     Italian Dressing Mix
# 12                   Satiny Chocolate Glaze
# 13                          Apple Crumb Pie
# 14          Addictive Sweet Potato Burritos
# 15               Swiss Chicken Casserole II
# 16             Old Fashioned Mac and Cheese
# 17  Delicious Raspberry Oatmeal Cookie Bars
# 18                Baked Slow Cooker Chicken
# 19                        Artichoke Chicken
#
#                                                     1  \
# 0                                  Golden Potato Soup
# 1                                 Baked Potato Soup I
# 2                                     Classic Goulash
# 3                 Rick's Special Buttercream Frosting
# 4                          Swiss Chicken Casserole II
# 5                             Bacon Ranch Pasta Salad
# 6                                Chicken Fajita Melts
# 7                       French Bread Rolls to Die For
# 8                                 Cajun Seafood Pasta
# 9             Chicken Makhani (Indian Butter Chicken)
# 10                         Best Ever Jalapeno Poppers
# 11                                       Potato Chips
# 12                        Chocolate Cavity Maker Cake
# 13                                    Apple Turnovers
# 14               Vegetarian Chickpea Sandwich Filling
# 15                      Garlic Cheese Chicken Rollups
# 16                       Delectable Marinated Chicken
# 17                      Oatmeal Peanut Butter Cookies
# 18            Slow Cooker Scalloped Potatoes with Ham
# 19  Chicken Breast Stuffed with Spinach Blue Chees...
#
#                                        2  \
# 0                      Mexican Casserole
# 1                   Kentucky Butter Cake
# 2              Shrimp Fettuccine Alfredo
# 3          Fluffy Peanut Butter Frosting
# 4                          Garlic Butter
# 5             Sesame Pasta Chicken Salad
# 6                        Lasagna Alfredo
# 7                     Peppy's Pita Bread
# 8                  Grilled Shrimp Scampi
# 9                Curried Coconut Chicken
# 10       Fried Chicken with Creamy Gravy
# 11                         Garlic Butter
# 12  Chocolate Fudge Buttercream Frosting
# 13                         Apple Squares
# 14                    Spaghetti Squash I
# 15             Crispy Herb Baked Chicken
# 16            Emily's Famous Hash Browns
# 17                   Pumpkin Gingerbread
# 18                Slow Cooker Enchiladas
# 19                    Chicken Piccata II
#
#                                                3  \
# 0                        Tomato Chicken Parmesan
# 1                       Bodacious Broccoli Salad
# 2     Fettuccine with Sweet Pepper-Cayenne Sauce
# 3                          Dark Chocolate Cake I
# 4                                   Potato Chips
# 5                       Cheesy Ranch Potato Bake
# 6                   Prize Winning Baby Back Ribs
# 7                    Crispy and Creamy Doughnuts
# 8                                   Basil Shrimp
# 9                                           Naan
# 10  Philly Cheesesteak Sandwich with Garlic Mayo
# 11       Broccoli with Garlic Butter and Cashews
# 12                 Double Chocolate Brownie Cake
# 13                                Lemon Pie Bars
# 14                     Black Bean and Salsa Soup
# 15               Chicken Breasts with Lime Sauce
# 16                           Happy Roast Chicken
# 17                Pumpkin Apple Streusel Muffins
# 18                   Slow Cooker Salisbury Steak
# 19            Penne Pasta with Spinach and Bacon
#
#                                          4  \
# 0                      Baked Potato Soup V
# 1                    Bacon and Tomato Cups
# 2                 Cheesy Chicken Meatballs
# 3      Whipped Cream Cream Cheese Frosting
# 4            Garlic Cheese Chicken Rollups
# 5                 Cabbage Fat-Burning Soup
# 6                     Southern Pulled Pork
# 7                             French Bread
# 8                                 Cioppino
# 9                    Peanut Butter Noodles
# 10  Authentic Louisiana Red Beans and Rice
# 11                    Toasted Garlic Bread
# 12         Chocolate Lovers' Favorite Cake
# 13                 Crustless Cranberry Pie
# 14  The Best Vegetarian Chili in the World
# 15                      Awesome Roast Beef
# 16            Tender Italian Baked Chicken
# 17                   Apple Strudel Muffins
# 18          Slow Cooker Creamy Potato Soup
# 19          Charleston Breakfast Casserole
#
#                                      5  \
# 0                  Baked Potato Soup I
# 1                              BLT Dip
# 2           Creamy Chicken on Linguine
# 3               Extreme Chocolate Cake
# 4                    Cheddar Ranch Dip
# 5                      Pepperoni Bread
# 6         The Best Chicken Fried Steak
# 7                      English Muffins
# 8             Grilled Marinated Shrimp
# 9                     Kung Pao Chicken
# 10                            Souvlaki
# 11                         Egg Noodles
# 12         Cream Cheese Pound Cake III
# 13                             Churros
# 14  California Grilled Veggie Sandwich
# 15     Brooklyn Girl's Penne Arrabiata
# 16     Absolutely Ultimate Potato Soup
# 17                       Apple Squares
# 18                     Slow Cooker Ham
# 19          Breakfast Upside Down Cake
#
#                                                     6  \
# 0                     Fried Chicken with Creamy Gravy
# 1                     Chocolate Lovers' Favorite Cake
# 2                                 Rice Balls a la Tim
# 3   Lemon Cake with Lemon Filling and Lemon Butter...
# 4                                  Awesome Roast Beef
# 5                   Fresh Strawberry Upside Down Cake
# 6                           Stuffed Chicken Valentino
# 7                              Burger or Hot Dog Buns
# 8                   Firecracker Grilled Alaska Salmon
# 9                       Vietnamese Fresh Spring Rolls
# 10                          Bourbon Whiskey BBQ Sauce
# 11                                  Ranch Dressing II
# 12                    Easy Chocolate Bundt Cake Glaze
# 13                          Chocolate Truffle Cookies
# 14                          Black Bean Vegetable Soup
# 15                               Chicken Scarpariello
# 16                                 Oh-So-Good Chicken
# 17                                Paul's Pumpkin Bars
# 18                 Marie's Easy Slow Cooker Pot Roast
# 19                     Balsamic-Glazed Salmon Fillets
#
#                                  7  \
# 0            Cheddar Baked Chicken
# 1       Day Before Mashed Potatoes
# 2         Famous Chicken Francaise
# 3        Creamy Chocolate Frosting
# 4               Fresh Tomato Salsa
# 5                    Fudge Puddles
# 6       Grill Master Chicken Wings
# 7         Simple Whole Wheat Bread
# 8              Creamy Pesto Shrimp
# 9              Mulligatawny Soup I
# 10                  Best Egg Rolls
# 11     Fried Rice Restaurant Style
# 12      Ruth's Grandma's Pie Crust
# 13           Cream Filled Cupcakes
# 14                     Lentil Soup
# 15     Manicotti Italian Casserole
# 16      Chicken Asparagus Roll-Ups
# 17    Pumpkin Cream Cheese Muffins
# 18    Tangy Slow Cooker Pork Roast
# 19  Slow Cooker Chicken Cacciatore
#
#                                                     8  \
# 0                                     Stuffed Peppers
# 1                                    Honey Bun Cake I
# 2   Feta and Bacon Stuffed Chicken with Onion Mash...
# 3                         Chocolate Cookie Cheesecake
# 4                           Crispy Herb Baked Chicken
# 5                                       Hot Pizza Dip
# 6                             Amazing Crusted Chicken
# 7                            Best Bread Machine Bread
# 8              Angel Hair Pasta with Shrimp and Basil
# 9                                 Asian Lettuce Wraps
# 10                                      Oaxacan Tacos
# 11                         Emily's Famous Hash Browns
# 12                                  Herb Roasted Pork
# 13                                 Triple Berry Crisp
# 14                  Sean's Falafel and Cucumber Sauce
# 15         Quick Chicken with Asparagus and Provolone
# 16                         Slow Cooker Beef Pot Roast
# 17                  Outrageous Chocolate Chip Cookies
# 18                                   Cabbage Rolls II
# 19                        Mexican Style Shredded Pork
#
#                                                     9
# 0                              Oven Fried Chicken III
# 1                                       Hot Pizza Dip
# 2   Best Ever Sausage with Peppers, Onions, and Beer!
# 3                                       Fudge Puddles
# 4                      Charleston Breakfast Casserole
# 5                            Easy Cream Cheese Danish
# 6                 Slow Cooker Italian Chicken Alfredo
# 7                                  Cinnamon Rolls III
# 8                                My Best Clam Chowder
# 9                   Sean's Falafel and Cucumber Sauce
# 10                              Real Homemade Tamales
# 11                                       Italian Peas
# 12                        One Bowl Chocolate Cake III
# 13                                        Ladyfingers
# 14                      Delicious Black Bean Burritos
# 15                       Creamy Potato Pork Chop Bake
# 16                                 Asian Beef Skewers
# 17                  Oatmeal Peanut Butter Cookies III
# 18                     Pork Chops for the Slow Cooker
# 19                    Chicken Breasts with Lime Sauce

# %% [markdown]
# Not super informative.. Let's try to extract the most characteristic words used in the recipe names for each cluster.

# %%
df = mldb.query("select * from rcp_merged")
ordered_names = recipe_names(df.index.values)
documents = [" ".join(ordered_names[df.cluster.astype(int).values == i]) for i in range(len(centroids))]
from sklearn.feature_extraction.text import CountVectorizer
from scipy.stats import rankdata
v = CountVectorizer(min_df=0.2, stop_words ="english")
td = v.fit_transform(documents).A
words = np.array(v.get_feature_names())

f = lambda x: rankdata(-x)
overall = td.sum(axis=0)
all_words = [list(words[(f(row) / f(overall-row)).argsort()]) for row in td]

# %%
import json
from ipywidgets import interact 
from IPython.display import IFrame, display
html = """
<script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.6/d3.min.js"></script>
<script src="http://opensource.datacratic.com/mldb-demo-resources/d3.layout.cloud.js"></script>
<script src="http://opensource.datacratic.com/mldb-demo-resources/wordcloud.js"></script>
<body> <script>drawCloud(%s)</script> </body>
"""
@interact 
def cluster_word_cloud(cluster=[0,len(all_words)-1]):
    num_words = 20
    cluster_words = [dict(size=num_words-i, text=w) for i, w in enumerate(all_words[cluster][:num_words])]
    display( IFrame("data:text/html," + (html % json.dumps(cluster_words)).replace('"',"'"), 850, 350) )
# Out:
#         <iframe
#             width="850"
#             height="350"
#             src="data:text/html,
# <script src='https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.6/d3.min.js'></script>
# <script src='http://opensource.datacratic.com/mldb-demo-resources/d3.layout.cloud.js'></script>
# <script src='http://opensource.datacratic.com/mldb-demo-resources/wordcloud.js'></script>
# <body> <script>drawCloud([{'text': 'thai', 'size': 20}, {'text': 'curry', 'size': 19}, {'text': 'asian', 'size': 18}, {'text': 'cuban', 'size': 17}, {'text': 'curried', 'size': 16}, {'text': 'chinese', 'size': 15}, {'text': 'japanese', 'size': 14}, {'text': 'leek', 'size': 13}, {'text': 'milk', 'size': 12}, {'text': 'meat', 'size': 11}, {'text': 'mango', 'size': 10}, {'text': 'lamb', 'size': 9}, {'text': 'stew', 'size': 8}, {'text': 'irish', 'size': 7}, {'text': 'german', 'size': 6}, {'text': 'authentic', 'size': 5}, {'text': 'carne', 'size': 4}, {'text': 'brazilian', 'size': 3}, {'text': 'polish', 'size': 2}, {'text': 'colcannon', 'size': 1}])</script> </body>
# "
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# None

# %% [markdown]
# Much better!

# %% [markdown]
# ## Where to next?
#
# Check out the other [Tutorials and Demos](/doc/#builtin/Demos.md.html).
