# %% [markdown]
# # Exploring Favourite Recipes
#
# [AllRecipes](http://allrecipes.com/) is a recipe website, where people can mark certain recipes as 'favourites'. A student named Jeremy Cohen [scraped some of this data for an excellent machine learning project](http://www.jeremymcohen.net/posts/taste/) and we'll use his dataset to demo how to do some unsupervised machine learning with MLDB.

# %% [markdown]
# The notebook cells below use `pymldb`'s `Connection` class to make [REST API](/doc/#builtin/WorkingWithRest.md.html) calls. You can check out the [Using `pymldb` Tutorial](/doc/nblink.html#_tutorials/Using pymldb Tutorial) for more details.

# %%
from pymldb import Connection
mldb = Connection()

# %% [markdown]
# The sequence of procedures below is based on the one explained in the [Mapping Reddit](/doc/nblink.html#_demos/Mapping Reddit) demo notebook.

# %%
print mldb.v1.datasets("rcp_raw").put({
    "type": "text.csv.tabular",
    "params": {
        "headers": ["user_id", "recipe_id"],
        "dataFileUrl": "https://raw.githubusercontent.com/jmcohen/taste/master/data/favorites.csv"
    }
})

print mldb.v1.procedures.post({
    "id": "rcp_import",
    "type": "transform",
    "params": {
        "inputDataset": "rcp_raw",
        "outputDataset": "recipes",
        "select": "pivot(recipe_id, 1) as *",
        "groupBy": "user_id", 
        "rowName": "user_id",
        "runOnCreation": True
    }
})

print mldb.v1.procedures.post({
    "id": "rcp_svd",
    "type" : "svd.train",
    "params" : {
        "trainingData": "select * from recipes",
        "columnOutputDataset" : "rcp_svd_embedding",
        "runOnCreation": True
    }
})

print mldb.v1.procedures.post({
    "id" : "rcp_kmeans",
    "type" : "kmeans.train",
    "params" : {
        "trainingData" : "select * from rcp_svd_embedding",
        "outputDataset" : "rcp_kmeans_clusters",
        "centroidsDataset" : "rcp_kmeans_centroids",
        "numClusters" : 20,
        "runOnCreation": True
    }
})

print mldb.v1.procedures.post({
    "id": "rcp_tsne",
    "type" : "tsne.train",
    "params" : {
        "trainingData" : "select * from rcp_svd_embedding",
        "rowOutputDataset" : "rcp_tsne_embedding",
        "runOnCreation": True
    }
})
# Out:
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>

# %% [markdown]
# Let's load up the recipe names so we can see what we clustered.

# %%
import numpy as np
import pandas as pd
import urllib2 
names = []
for i, l in enumerate(urllib2.urlopen("https://raw.githubusercontent.com/jmcohen/taste/master/data/recipes.csv")):
    pieces = l.strip().split(",")
    names.append(",".join(pieces[1:]).replace("&#34;", '"').replace("'", "'"))

names = np.array(names)

def recipe_names(row_names):
    return names[ [int(x.split("|")[0]) for x in row_names] ]

# %% [markdown]
# Let's look a the closest recipes to each cluster centroid to try to get a sense of what the clusters mean.

# %%
centroids = mldb.query("select * from rcp_kmeans_centroids order by implicit_cast(rowName())")
import json
rows = []
for x in json.loads(centroids.to_json(orient="records")):
    result = mldb.v1.datasets("rcp_svd_embedding").routes.neighbours.get(**x)
    rows.append(recipe_names(r[0] for r in result.json()))
pd.DataFrame(rows)
# Out:
#                                           0  \
# 0                      Italian Dressing Mix
# 1               Magic Peanut Butter Middles
# 2           Addictive Sweet Potato Burritos
# 3                      Kentucky Butter Cake
# 4             Chicken and Biscuit Casserole
# 5   Delicious Raspberry Oatmeal Cookie Bars
# 6                 Baked Slow Cooker Chicken
# 7                           Apple Crumb Pie
# 8                Swiss Chicken Casserole II
# 9            Chocolate Covered Strawberries
# 10               Pesto Cheesy Chicken Rolls
# 11                     Chicken Tikka Masala
# 12            Super-Delicious Zuppa Toscana
# 13                      Baked Potato Soup I
# 14                        Artichoke Chicken
# 15       Taqueria Style Tacos - Carne Asada
# 16             Old Fashioned Mac and Cheese
# 17                         French Baguettes
# 18                        Simple White Cake
# 19                       Golden Potato Soup
#
#                                                     1  \
# 0                                        Potato Chips
# 1                        Chewy Peanut Butter Brownies
# 2                Vegetarian Chickpea Sandwich Filling
# 3                          Cream Cheese Sugar Cookies
# 4                                     Classic Goulash
# 5                                 Pumpkin Gingerbread
# 6             Slow Cooker Scalloped Potatoes with Ham
# 7                                     Apple Turnovers
# 8                       Garlic Cheese Chicken Rollups
# 9                                Toasted Garlic Bread
# 10                               Chicken Fajita Melts
# 11            Chicken Makhani (Indian Butter Chicken)
# 12                         Sesame Pasta Chicken Salad
# 13                           Bodacious Broccoli Salad
# 14  Chicken Breast Stuffed with Spinach Blue Chees...
# 15                         Best Ever Jalapeno Poppers
# 16                       Delectable Marinated Chicken
# 17                      French Bread Rolls to Die For
# 18                              Dark Chocolate Cake I
# 19                    Fried Chicken with Creamy Gravy
#
#                                           2  \
# 0   Broccoli with Garlic Butter and Cashews
# 1                             Fudge Puddles
# 2                 Black Bean and Salsa Soup
# 3                         Autumn Cheesecake
# 4                 Shrimp Fettuccine Alfredo
# 5                             Apple Squares
# 6                    Slow Cooker Enchiladas
# 7                             Apple Squares
# 8                 Crispy Herb Baked Chicken
# 9                             Garlic Butter
# 10                          Lasagna Alfredo
# 11            Vietnamese Fresh Spring Rolls
# 12                  Bacon Ranch Pasta Salad
# 13                         American Lasagna
# 14           Balsamic-Glazed Salmon Fillets
# 15                    Real Homemade Tamales
# 16               Emily's Famous Hash Browns
# 17                       Peppy's Pita Bread
# 18             Special Buttercream Frosting
# 19                        Mexican Casserole
#
#                                                3  \
# 0                                  Garlic Butter
# 1                     No Bake Chocolate Oat Bars
# 2                             Spaghetti Squash I
# 3                         Irish Cream Bundt Cake
# 4     Fettuccine with Sweet Pepper-Cayenne Sauce
# 5                          Apple Strudel Muffins
# 6                    Slow Cooker Salisbury Steak
# 7                        Crustless Cranberry Pie
# 8                             Awesome Roast Beef
# 9                                 Sauteed Apples
# 10                  Prize Winning Baby Back Ribs
# 11                       Curried Coconut Chicken
# 12                      Cheesy Ranch Potato Bake
# 13                         Bacon and Tomato Cups
# 14                            Chicken Piccata II
# 15  Philly Cheesesteak Sandwich with Garlic Mayo
# 16                           Happy Roast Chicken
# 17                                  French Bread
# 18           Rick's Special Buttercream Frosting
# 19                    A Good Easy Garlic Chicken
#
#                                          4                                5  \
# 0                              Egg Noodles       Roasted Garlic Cauliflower
# 1                      Frosted Banana Bars    Fluffy Peanut Butter Frosting
# 2   The Best Vegetarian Chili in the World        Black Bean Vegetable Soup
# 3                       Cinnamon Rolls III  Chocolate Lovers' Favorite Cake
# 4               Creamy Chicken on Linguine         Cheesy Chicken Meatballs
# 5            Oatmeal Peanut Butter Cookies   Pumpkin Apple Streusel Muffins
# 6           Slow Cooker Creamy Potato Soup                  Slow Cooker Ham
# 7                                  Churros                   Lemon Pie Bars
# 8              Manicotti Italian Casserole                Brunch Enchiladas
# 9                     Baked French Fries I               Sarah's Applesauce
# 10                    Southern Pulled Pork        Stuffed Chicken Valentino
# 11                   Peanut Butter Noodles                 Kung Pao Chicken
# 12       Fresh Strawberry Upside Down Cake                    Fudge Puddles
# 13                           Hot Pizza Dip                          BLT Dip
# 14             Mexican Style Shredded Pork   Charleston Breakfast Casserole
# 15  Authentic Louisiana Red Beans and Rice        Bourbon Whiskey BBQ Sauce
# 16            Tender Italian Baked Chicken  Absolutely Ultimate Potato Soup
# 17                         English Muffins         Simple Whole Wheat Bread
# 18                   Cream Filled Cupcakes                Chocolate Ganache
# 19                     Baked Potato Soup I              Baked Potato Soup V
#
#                                            6  \
# 0   Absolutely Fabulous Greek/House Dressing
# 1                 Caramel Shortbread Squares
# 2         California Grilled Veggie Sandwich
# 3                           Honey Bun Cake I
# 4                   Famous Chicken Francaise
# 5                    Morning Glory Muffins I
# 6               Tangy Slow Cooker Pork Roast
# 7                                Ladyfingers
# 8            Chicken Breasts with Lime Sauce
# 9                         Great Garlic Bread
# 10              The Best Chicken Fried Steak
# 11                                  Souvlaki
# 12                       Barbie's Tuna Salad
# 13                                 BLT Salad
# 14            Slow Cooker Chicken Cacciatore
# 15                Amy's Cilantro Cream Sauce
# 16                        Oh-So-Good Chicken
# 17               Crispy and Creamy Doughnuts
# 18                         Buttercream Icing
# 19                    Oven Fried Chicken III
#
#                                      7  \
# 0                         Italian Peas
# 1    Oatmeal Peanut Butter Cookies III
# 2                          Lentil Soup
# 3                 Bake Sale Lemon Bars
# 4                  Rice Balls a la Tim
# 5         Health Nut Blueberry Muffins
# 6   Marie's Easy Slow Cooker Pot Roast
# 7            Chocolate Truffle Cookies
# 8             Slow Cooker London Broil
# 9            Oven Roasted Red Potatoes
# 10          Grill Master Chicken Wings
# 11                 Mulligatawny Soup I
# 12              Broccoli Chicken Divan
# 13                     Pepperoni Bread
# 14     Chicken Breasts with Lime Sauce
# 15     Fried Chicken with Creamy Gravy
# 16          Chicken Asparagus Roll-Ups
# 17              Burger or Hot Dog Buns
# 18              Extreme Chocolate Cake
# 19                     Stuffed Peppers
#
#                                                     8  \
# 0                         Fried Rice Restaurant Style
# 1                                        Cookie Balls
# 2                   Sean's Falafel and Cucumber Sauce
# 3                 Award Winning Peaches and Cream Pie
# 4   Feta and Bacon Stuffed Chicken with Onion Mash...
# 5                      Low-Fat Blueberry Bran Muffins
# 6                                    Cabbage Rolls II
# 7                                  Triple Berry Crisp
# 8                                Chicken Scarpariello
# 9                               Oven Roasted Potatoes
# 10                            Amazing Crusted Chicken
# 11                   Russian Mushroom and Potato Soup
# 12                           Cabbage Fat-Burning Soup
# 13                         Day Before Mashed Potatoes
# 14                         Breakfast Upside Down Cake
# 15                                     Best Egg Rolls
# 16                         Slow Cooker Beef Pot Roast
# 17                           Best Bread Machine Bread
# 18                Whipped Cream Cream Cheese Frosting
# 19                             Broccoli Chicken Divan
#
#                                                     9
# 0                                   Ranch Dressing II
# 1             Delicious Raspberry Oatmeal Cookie Bars
# 2                       Delicious Black Bean Burritos
# 3                                     Golden Rum Cake
# 4   Best Ever Sausage with Peppers, Onions, and Beer!
# 5                   Outrageous Chocolate Chip Cookies
# 6                      Pork Chops for the Slow Cooker
# 7                            French Breakfast Muffins
# 8                                        Kona Chicken
# 9               Strawberry Oatmeal Breakfast Smoothie
# 10                Slow Cooker Italian Chicken Alfredo
# 11                                           Cioppino
# 12                                     Sesame Noodles
# 13                              Antipasto Pasta Salad
# 14                 Penne Pasta with Spinach and Bacon
# 15                                   Mexican Rice III
# 16                                 Asian Beef Skewers
# 17                                      Mall Pretzels
# 18                          Creamy Chocolate Frosting
# 19                 Country Fried Steak and Milk Gravy

# %% [markdown]
# Not super informative.. Let's try to extract the most characteristic words used in the recipe names for each cluster.

# %%
df = mldb.query("select * from merge(rcp_svd_embedding, rcp_tsne_embedding, rcp_kmeans_clusters)")
ordered_names = recipe_names(df.index.values)
documents = [" ".join(ordered_names[df.cluster.astype(int).values == i]) for i in range(len(centroids))]
from sklearn.feature_extraction.text import CountVectorizer
from scipy.stats import rankdata
v = CountVectorizer(min_df=0.2, stop_words ="english")
td = v.fit_transform(documents).A
words = np.array(v.get_feature_names())

f = lambda x: rankdata(-x)
overall = td.sum(axis=0)
all_words = [list(words[(f(row) / f(overall-row)).argsort()]) for row in td]

# %%
import json
from ipywidgets import interact 
from IPython.display import IFrame, display
html = """
<script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.6/d3.min.js"></script>
<script src="http://opensource.datacratic.com/mldb-demo-resources/d3.layout.cloud.js"></script>
<script src="http://opensource.datacratic.com/mldb-demo-resources/wordcloud.js"></script>
<body> <script>drawCloud(%s)</script> </body>
"""
@interact 
def cluster_word_cloud(cluster=[0,len(all_words)-1]):
    num_words = 20
    cluster_words = [dict(size=num_words-i, text=w) for i, w in enumerate(all_words[cluster][:num_words])]
    display( IFrame("data:text/html," + (html % json.dumps(cluster_words)).replace('"',"'"), 850, 350) )
# Out:
#         <iframe
#             width="850"
#             height="350"
#             src="data:text/html,
# <script src='https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.6/d3.min.js'></script>
# <script src='http://opensource.datacratic.com/mldb-demo-resources/d3.layout.cloud.js'></script>
# <script src='http://opensource.datacratic.com/mldb-demo-resources/wordcloud.js'></script>
# <body> <script>drawCloud([{'text': 'smoothie', 'size': 20}, {'text': 'punch', 'size': 19}, {'text': 'potatoes', 'size': 18}, {'text': 'fruit', 'size': 17}, {'text': 'strawberry', 'size': 16}, {'text': 'lemonade', 'size': 15}, {'text': 'mashed', 'size': 14}, {'text': 'apples', 'size': 13}, {'text': 'cider', 'size': 12}, {'text': 'chips', 'size': 11}, {'text': 'garlic', 'size': 10}, {'text': 'watermelon', 'size': 9}, {'text': 'strawberries', 'size': 8}, {'text': 'twice', 'size': 7}, {'text': 'iced', 'size': 6}, {'text': 'party', 'size': 5}, {'text': 'carrots', 'size': 4}, {'text': 'marinara', 'size': 3}, {'text': 'cocoa', 'size': 2}, {'text': 'margarita', 'size': 1}])</script> </body>
# "
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# None

# %% [markdown]
# Much better!

# %% [markdown]
# ## Where to next?
#
# Check out the other [Tutorials and Demos](/doc/#builtin/Demos.md.html).
