# %% [markdown]
# # Exploring Favourite Recipes
#
# [AllRecipes](http://allrecipes.com/) is a recipe website, where people can mark certain recipes as 'favourites'. A student named Jeremy Cohen [scraped some of this data for an excellent machine learning project](http://www.jeremymcohen.net/posts/taste/) and we'll use his dataset to demo how to do some unsupervised machine learning with MLDB.

# %% [markdown]
# The notebook cells below use `pymldb`'s `Connection` class to make [REST API](../../../../doc/#builtin/WorkingWithRest.md.html) calls. You can check out the [Using `pymldb` Tutorial](../../../../doc/nblink.html#_tutorials/Using pymldb Tutorial) for more details.

# %%
from pymldb import Connection
mldb = Connection("http://localhost/")

# %% [markdown]
# The sequence of procedures below is based on the one explained in the [Mapping Reddit](../../../../doc/nblink.html#_demos/Mapping Reddit) demo notebook.

# %%
print mldb.put('/v1/procedures/import_rcp', {
    "type": "import.text",
    "params": {
        "headers": ["user_id", "recipe_id"],
        "dataFileUrl": "https://raw.githubusercontent.com/jmcohen/taste/master/data/favorites.csv",
        "outputDataset": "rcp_raw",
        "runOnCreation": True
    }
})

print mldb.post('/v1/procedures', {
    "id": "rcp_import",
    "type": "transform",
    "params": {
        "inputData": "select pivot(recipe_id, 1) as * named user_id from rcp_raw group by user_id",
        "outputDataset": "recipes",
        "runOnCreation": True
    }
})
# Out:
# <Response [201]>
# <Response [201]>

# %%
print mldb.post('/v1/procedures', {
    "id": "rcp_svd",
    "type" : "svd.train",
    "params" : {
        "trainingData": "select * from recipes",
        "columnOutputDataset" : "rcp_svd_embedding_raw",
        "runOnCreation": True
    }
})

print mldb.put('/v1/procedures/rcp_clean_svd', {
    'type': 'transform',
    'params': {
        'inputData': '''select * named jseval(
                            'return s.substr(0, s.indexOf("|"))',
                            's', rowName()) from rcp_svd_embedding_raw''',
        'outputDataset': {'id': 'rcp_svd_embedding',
                          'type': 'embedding',
                          'params': {'metric': 'cosine'}},
        'runOnCreation': True
    }
})

print mldb.post('/v1/procedures', {
    "id" : "rcp_kmeans",
    "type" : "kmeans.train",
    "params" : {
        "trainingData" : "select * from rcp_svd_embedding",
        "outputDataset" : "rcp_kmeans_clusters",
        "centroidsDataset" : "rcp_kmeans_centroids",
        "numClusters" : 15,
        "runOnCreation": True
    }
})
# Out:
# <Response [201]>
# <Response [201]>
# <Response [201]>

# %% [markdown]
# Let's load up the recipe names so we can see what we clustered. First we'll read the file and then extract and clean the recipe names.

# %%
print mldb.put('/v1/procedures/import_rcp_names_raw', {
    'type': 'import.text',
    'params': {
        'dataFileUrl': 'https://raw.githubusercontent.com/jmcohen/taste/master/data/recipes.csv',
        'outputDataset': "rcp_names_raw",
        'delimiter':'',
        'quotechar':'',
        'runOnCreation': True
    }
})

print mldb.put('/v1/procedures/rcp_names_import', {
    'type': 'transform',
    'params': {
        'inputData': '''
            select jseval(
               'return s.substr(s.indexOf(",") + 1)
                .replace(/&#34;/g, "")
                .replace(/&#174;/g, "");',
            's', lineText) as name
            named implicit_cast(rowName()) - 1
            from rcp_names_raw
        ''',
        'outputDataset': 'rcp_names',
        'runOnCreation': True
    }
})
# Out:
# <Response [201]>
# <Response [201]>

# %%
def recipe_name(row_name):
    """ simple utility that returns the name of a recipe from its id (rowName() in the datasets) """
    return mldb.get('/v1/query', q="select name from rcp_names where rowName() = '{}'".format(row_name),
                   format='aos').json()[0]['name']

# %% [markdown]
# Let's look a the closest recipes to each cluster centroid to try to get a sense of what the clusters mean.

# %%
import pandas as pd
centroids = mldb.get('/v1/query', q="select * from rcp_kmeans_centroids order by implicit_cast(rowName())",
                      format='aos', rowNames="false").json()
rows = []
for c in centroids:
    neighbours = mldb.get('/v1/datasets/rcp_svd_embedding/routes/neighbours', numNeighbours=10, **c).json()
    rows.append([recipe_name(n[0]) for n in neighbours])
pd.DataFrame(rows)
# Out:
#                                               0  \
# 0             Traditional Christmas Cheese Ball
# 1   Fried Cabbage with Bacon, Onion, and Garlic
# 2                         Vegan Red Lentil Soup
# 3                                  Cheese Grits
# 4                                  Coffee Shake
# 5                                   Chicago Dip
# 6                            Lemon Chiffon Cake
# 7                             Chap Chee Noodles
# 8                  Angel's Chunky Chicken Salad
# 9      Apple Coffee Cake With Brown Sugar Sauce
# 10                       Fabulous French Loaves
# 11             Cinnamon Sugar Butter Cookies II
# 12            Colette's Smoked Sausage Fritatta
# 13                            Spicy Flank Steak
# 14              Slow Cooker Thanksgiving Turkey
#
#                                         1  \
# 0                Superb Sauteed Mushrooms
# 1                         Sausage Flowers
# 2                     Lentils And Spinach
# 3                      Teriyaki Mushrooms
# 4                       Chocolate Wontons
# 5                        Baked Potato Dip
# 6                   Whipped Cream Filling
# 7                           African Curry
# 8                           Taco Salad II
# 9                 Blueberry Coffee Cake I
# 10              Soft Onion Sandwich Rolls
# 11                   Oatmeal Whoopie Pies
# 12  Filet Mignons With Pepper Cream Sauce
# 13              Flip Flop Grilled Chicken
# 14     Slow Cooker Split Pea Sausage Soup
#
#                                                     2  \
# 0                            Old School Mac n' Cheese
# 1                              Ruby Drive Sloppy Joes
# 2   Swiss Chard with Garbanzo Beans and Fresh Toma...
# 3           Hot Artichoke Dip with Sun-Dried Tomatoes
# 4                               Tasty Salad Seasoning
# 5                            Cheesy  Potato Casserole
# 6                                         Pro Ganache
# 7                               Asian Barbequed Steak
# 8                               Cheesy Fried Potatoes
# 9                 Blueberry Cream Cheese Pound Cake I
# 10                             Mama D's Italian Bread
# 11            Chocolate Coated Peanut Butter Crackers
# 12                                 Chicken Scallopini
# 13                          Blissful Rosemary Chicken
# 14                             Slow Cooker Pork Chops
#
#                                                     3  \
# 0                                 Baked Denver Omelet
# 1                                 Sesame Noodle Salad
# 2                                     Mock Tuna Salad
# 3                      Melt In Your Mouth Chicken Pie
# 4                                   Fabulous Fargozas
# 5                               Fantastic Mexican Dip
# 6                               Strawberry Cream Roll
# 7   Sesame Crusted Mahi Mahi with Soy Shiso Ginger...
# 8                         Incredible Potato Casserole
# 9                   Cranberry Upside-Down Coffee Cake
# 10                                         Tasty Buns
# 11                               Snickerdoodle Cake I
# 12                                Hidden Cheeseburger
# 13                                       Chicken Melt
# 14                         Slow Cooker BBQ Pork Chops
#
#                                       4  \
# 0                          Beer Burgers
# 1                  Tomato Bacon Squares
# 2       Mediterranean Chickpea Salad II
# 3   Three Cheese Macaroni with Tomatoes
# 4             Dad's Kentucky Home Fries
# 5                   Zippy Egg Casserole
# 6                  Glorious Sponge Cake
# 7                    Killer Shrimp Soup
# 8                             Baked Ham
# 9                      Apple Bundt Cake
# 10                 Bread Machine Bagels
# 11                         Hockey Pucks
# 12                   Bourbon-Glazed Ham
# 13          Sweet and Sour Pork Patties
# 14                 Easy Slow Cooker Ham
#
#                                           5  \
# 0           Healthier Oven Roasted Potatoes
# 1                       Man-Lovin' Potatoes
# 2                Fava Bean Breakfast Spread
# 3     Southwestern Cauliflower and Ham Soup
# 4                         Orange Juice Cake
# 5                              Mini Reubens
# 6             Fabulous Fudge Chocolate Cake
# 7                   Baked Pork Spring Rolls
# 8                      Broccoli Casserole I
# 9                              Pear Bread I
# 10           Grandma's English Muffin Bread
# 11                             Passion Bars
# 12             Peter's Baked Stuffed Onions
# 13      Italian Chicken with Pesto Potatoes
# 14  Slow Cooker Scalloped Potatoes with Ham
#
#                                                     6  \
# 0                                      Sunshine Juice
# 1                The Meatball that Fell Off the Table
# 2                                   Garbanzo Stir-Fry
# 3                             Ricotta Cheese Pancakes
# 4                                          Fugi Salad
# 5                                Baked Potato Salad I
# 6                               Wedding Cake Frosting
# 7                               Adrienne's Tom Ka Gai
# 8                            Breaded Parmesan Chicken
# 9                              Apple Honey Bundt Cake
# 10                                  Sourdough Starter
# 11                                     Kitty Kat Bars
# 12  Gorgonzola Stuffed Chicken Breasts Wrapped in ...
# 13                                  My Chicken Milano
# 14                     Slow Cooker Creamy Potato Soup
#
#                                      7  \
# 0          Mistakenly Zesty Pork Chops
# 1            Johnny Marzetti Casserole
# 2             Vegetarian Tortilla Soup
# 3                        Berry Cobbler
# 4                Amber's Peanut Butter
# 5                    Spaghetti Salad I
# 6        One Bowl Buttercream Frosting
# 7                         Thai Noodles
# 8             Cold Tuna Macaroni Salad
# 9                    Cherry Pound Cake
# 10                     English Muffins
# 11  Disappearing  Marshmallow Brownies
# 12     Pepperidge Farm Beef Wellington
# 13                      Fusion Chicken
# 14                    Busy Day Chicken
#
#                                                8  \
# 0                               Stuffed Potatoes
# 1                      Sassy Tailgate Sandwiches
# 2                            Eggplant Sandwiches
# 3   Fettuccine in Creamy Mushroom and Sage Sauce
# 4                            Maple-Vanilla Syrup
# 5                  Mary's Roasted Red Pepper Dip
# 6                 Stabilized Whipped Cream Icing
# 7                  Sharon's Scrumptious Souvlaki
# 8                          Meat Filled Manicotti
# 9                        Apple Butter Spice Cake
# 10               Colleen's Potato Crescent Rolls
# 11                     Monkey Peanut Butter Bars
# 12                     Sour Cream Chicken Quiche
# 13      Spinach, Egg, and Pancetta with Linguine
# 14                     Slow Cooker Kielbasa Stew
#
#                                           9
# 0                           Noodles Alfredo
# 1                             Israeli Salad
# 2   Hariton's 'Famous' Vegetarian Casserole
# 3                      Brown Sugar Biscuits
# 4                  Bananas in Caramel Sauce
# 5     Aunt Phyllis' Magnificent Cheese Ball
# 6                           Lemon Gold Cake
# 7              Barbequed Thai Style Chicken
# 8              Ham, Potato, and Cheese Soup
# 9               Apple Cake and Butter Sauce
# 10                      Italian Bread Bowls
# 11                         Cinnabun Cookies
# 12                Spinach and Bacon Chicken
# 13             Delicious Baked Chicken Kiev
# 14                       Cabbage Patch Stew

# %% [markdown]
# Not super informative.. Let's try to extract the most characteristic words used in the recipe names for each cluster.

# %% [markdown]
# We'll start by preprocessing the recipe names a bit : taking out a few punctuations and convert to lowercase.

# %% [markdown]
# And then for a given cluster, we will count the words taken from the recipe names, after having filtered stop words. This is all done in one (big) query.

# %%
print mldb.put('/v1/functions/filter_stopwords', {'type': 'filter_stopwords'})

print mldb.put('/v1/procedures/sum_words_per_cluster', {
    'type': 'transform',
    'params': {
        'inputData': """
        SELECT
        sum(
            filter_stopwords({
                words: {
                    tokenize(lower(name), {splitchars:' ''()",', min_token_length: 4}) as *
                }
            })[words]
        ) as *
        NAMED cluster
        FROM merge(rcp_names, rcp_kmeans_clusters)
        GROUP BY cluster
        """,
        'outputDataset': 'rcp_cluster_word_counts',
        'runOnCreation': True
    }
})
# Out:
# <Response [201]>
# <Response [201]>

# %% [markdown]
# Here is what the created dataset looks like:

# %%
mldb.query('select * from rcp_cluster_word_counts order by implicit_cast(rowName())')
# Out:
#           absolutely  accidental  adam  addicting  ahead  aimee  albondigas  \
# _rowName
# 0                  1           1     1          1      1      1           1
# 1                  2         NaN   NaN        NaN    NaN    NaN         NaN
# 2                  1         NaN   NaN        NaN      1    NaN         NaN
# 3                  1         NaN   NaN        NaN    NaN    NaN         NaN
# 4                  3         NaN     1        NaN    NaN    NaN         NaN
# 5                  1         NaN   NaN        NaN      2    NaN         NaN
# 6                NaN         NaN   NaN        NaN    NaN    NaN         NaN
# 7                  2         NaN   NaN        NaN    NaN    NaN           2
# 8                NaN           1   NaN        NaN    NaN    NaN         NaN
# 9                  2         NaN   NaN        NaN    NaN    NaN         NaN
# 10               NaN         NaN   NaN        NaN    NaN    NaN         NaN
# 11               NaN         NaN   NaN        NaN    NaN    NaN         NaN
# 12               NaN         NaN   NaN        NaN    NaN    NaN         NaN
# 13               NaN         NaN   NaN        NaN    NaN    NaN         NaN
# 14               NaN         NaN   NaN        NaN    NaN    NaN         NaN
#
#           alfredo  alla  almond   ...     rump  sarge  sauerbraten  slower  \
# _rowName                          ...
# 0               2     1       1   ...      NaN    NaN          NaN     NaN
# 1               3   NaN     NaN   ...      NaN    NaN          NaN     NaN
# 2               1   NaN     NaN   ...      NaN    NaN          NaN     NaN
# 3               2     1       5   ...      NaN    NaN          NaN     NaN
# 4               2   NaN      10   ...      NaN    NaN          NaN     NaN
# 5               7   NaN       1   ...      NaN    NaN          NaN     NaN
# 6             NaN   NaN       1   ...      NaN    NaN          NaN     NaN
# 7               1     1       1   ...      NaN    NaN          NaN     NaN
# 8               9   NaN       1   ...      NaN    NaN          NaN     NaN
# 9             NaN   NaN       6   ...      NaN    NaN          NaN     NaN
# 10            NaN   NaN     NaN   ...      NaN    NaN          NaN     NaN
# 11            NaN   NaN       6   ...      NaN    NaN          NaN     NaN
# 12              5     1       1   ...      NaN    NaN          NaN     NaN
# 13              2     2     NaN   ...      NaN    NaN          NaN     NaN
# 14              2   NaN     NaN   ...        1      2            1       1
#
#           splendicious  superheated  texas-style  tipsy  western-style  \
# _rowName
# 0                  NaN          NaN          NaN    NaN            NaN
# 1                  NaN          NaN          NaN    NaN            NaN
# 2                  NaN          NaN          NaN    NaN            NaN
# 3                  NaN          NaN          NaN    NaN            NaN
# 4                  NaN          NaN          NaN    NaN            NaN
# 5                  NaN          NaN          NaN    NaN            NaN
# 6                  NaN          NaN          NaN    NaN            NaN
# 7                  NaN          NaN          NaN    NaN            NaN
# 8                  NaN          NaN          NaN    NaN            NaN
# 9                  NaN          NaN          NaN    NaN            NaN
# 10                 NaN          NaN          NaN    NaN            NaN
# 11                 NaN          NaN          NaN    NaN            NaN
# 12                 NaN          NaN          NaN    NaN            NaN
# 13                 NaN          NaN          NaN    NaN            NaN
# 14                   1            1            2      1              1
#
#           western
# _rowName
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14              1
#
# [15 rows x 3319 columns]

# %% [markdown]
# We can use this to create a TF-IDF score for each word in the cluster. Basically this score will give us an idea of the relative importance of a each word in a given cluster.

# %%
print mldb.put('/v1/procedures/train_tfidf', {
     'type': 'tfidf.train',
     'params': {
         'trainingData': 'select * from rcp_cluster_word_counts',
         'modelFileUrl': 'file:///models/rcp_tfidf.idf',
         'functionName': 'rcp_tfidf',
         'runOnCreation': True
    }
})

print mldb.put('/v1/procedures/apply_tfidf', {
     'type': 'transform',
     'params': {
         'inputData': 'select rcp_tfidf({input: {*}})[output] as * from rcp_cluster_word_counts',
         'outputDataset': 'rcp_cluster_word_scores',
         'runOnCreation': True
    }
})
# Out:
# <Response [201]>
# <Response [201]>

# %% [markdown]
# In the resulting dataset, the counts have been replaced by a score.

# %%
mldb.query("select * from rcp_cluster_word_scores order by implicit_cast(rowName())")
# Out:
#           absolutely  accidental     adam  addicting      ahead     aimee  \
# _rowName
# 0           5.912902     7.00971  7.00971   7.414874   6.722329  7.414874
# 1          11.825804         NaN      NaN        NaN        NaN       NaN
# 2           5.912902         NaN      NaN        NaN   6.722329       NaN
# 3           5.912902         NaN      NaN        NaN        NaN       NaN
# 4          17.738707         NaN  7.00971        NaN        NaN       NaN
# 5           5.912902         NaN      NaN        NaN  13.444658       NaN
# 6                NaN         NaN      NaN        NaN        NaN       NaN
# 7          11.825804         NaN      NaN        NaN        NaN       NaN
# 8                NaN     7.00971      NaN        NaN        NaN       NaN
# 9          11.825804         NaN      NaN        NaN        NaN       NaN
# 10               NaN         NaN      NaN        NaN        NaN       NaN
# 11               NaN         NaN      NaN        NaN        NaN       NaN
# 12               NaN         NaN      NaN        NaN        NaN       NaN
# 13               NaN         NaN      NaN        NaN        NaN       NaN
# 14               NaN         NaN      NaN        NaN        NaN       NaN
#
#           albondigas    alfredo       alla     almond    ...         rump  \
# _rowName                                                 ...
# 0            7.00971  11.252242   6.317465   5.712832    ...          NaN
# 1                NaN  16.878364        NaN        NaN    ...          NaN
# 2                NaN   5.626121        NaN        NaN    ...          NaN
# 3                NaN  11.252242   6.317465  28.564162    ...          NaN
# 4                NaN  11.252242        NaN  57.128323    ...          NaN
# 5                NaN  39.382848        NaN   5.712832    ...          NaN
# 6                NaN        NaN        NaN   5.712832    ...          NaN
# 7           14.01942   5.626121   6.317465   5.712832    ...          NaN
# 8                NaN  50.635091        NaN   5.712832    ...          NaN
# 9                NaN        NaN        NaN  34.276994    ...          NaN
# 10               NaN        NaN        NaN        NaN    ...          NaN
# 11               NaN        NaN        NaN  34.276994    ...          NaN
# 12               NaN  28.130606   6.317465   5.712832    ...          NaN
# 13               NaN  11.252242  12.634931        NaN    ...          NaN
# 14               NaN  11.252242        NaN        NaN    ...     7.414874
#
#               sarge  sauerbraten    slower  splendicious  superheated  \
# _rowName
# 0               NaN          NaN       NaN           NaN          NaN
# 1               NaN          NaN       NaN           NaN          NaN
# 2               NaN          NaN       NaN           NaN          NaN
# 3               NaN          NaN       NaN           NaN          NaN
# 4               NaN          NaN       NaN           NaN          NaN
# 5               NaN          NaN       NaN           NaN          NaN
# 6               NaN          NaN       NaN           NaN          NaN
# 7               NaN          NaN       NaN           NaN          NaN
# 8               NaN          NaN       NaN           NaN          NaN
# 9               NaN          NaN       NaN           NaN          NaN
# 10              NaN          NaN       NaN           NaN          NaN
# 11              NaN          NaN       NaN           NaN          NaN
# 12              NaN          NaN       NaN           NaN          NaN
# 13              NaN          NaN       NaN           NaN          NaN
# 14        14.829748     7.414874  7.414874      7.414874     7.414874
#
#           texas-style     tipsy  western-style   western
# _rowName
# 0                 NaN       NaN            NaN       NaN
# 1                 NaN       NaN            NaN       NaN
# 2                 NaN       NaN            NaN       NaN
# 3                 NaN       NaN            NaN       NaN
# 4                 NaN       NaN            NaN       NaN
# 5                 NaN       NaN            NaN       NaN
# 6                 NaN       NaN            NaN       NaN
# 7                 NaN       NaN            NaN       NaN
# 8                 NaN       NaN            NaN       NaN
# 9                 NaN       NaN            NaN       NaN
# 10                NaN       NaN            NaN       NaN
# 11                NaN       NaN            NaN       NaN
# 12                NaN       NaN            NaN       NaN
# 13                NaN       NaN            NaN       NaN
# 14          14.829748  7.414874       7.414874  7.414874
#
# [15 rows x 3319 columns]

# %% [markdown]
# If we transpose that dataset, we will be able to get the highest scored words for each cluster, and we can display them nicely in a word cloud.

# %%
import json
from ipywidgets import interact 
from IPython.display import IFrame, display
html = """
<script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.6/d3.min.js"></script>
<script src="http://opensource.datacratic.com/mldb-demo-resources/d3.layout.cloud.js"></script>
<script src="http://opensource.datacratic.com/mldb-demo-resources/wordcloud.js"></script>
<body> <script>drawCloud(%s)</script> </body>
"""

@interact 
def cluster_word_cloud(cluster=[0, len(centroids)]):
    num_words = 20
    cluster_words = mldb.get(
        '/v1/query',
        q="""
            SELECT rowName() as text
            FROM transpose(rcp_cluster_word_scores)
            ORDER BY "{0}" DESC
            LIMIT {1}
          """.format(cluster, num_words),
        format='aos',
        rowNames=0
    ).json()
    for i,x in enumerate(cluster_words):
        x['size'] = num_words - i
    display( IFrame("data:text/html," + (html % json.dumps(cluster_words)).replace('"',"'"), 850, 350) )
# Out:
#         <iframe
#             width="850"
#             height="350"
#             src="data:text/html,
# <script src='https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.6/d3.min.js'></script>
# <script src='http://opensource.datacratic.com/mldb-demo-resources/d3.layout.cloud.js'></script>
# <script src='http://opensource.datacratic.com/mldb-demo-resources/wordcloud.js'></script>
# <body> <script>drawCloud([{'text': 'chicken', 'size': 20}, {'text': 'soup', 'size': 19}, {'text': 'sauce', 'size': 18}, {'text': 'shrimp', 'size': 17}, {'text': 'thai', 'size': 16}, {'text': 'grilled', 'size': 15}, {'text': 'pork', 'size': 14}, {'text': 'salmon', 'size': 13}, {'text': 'spicy', 'size': 12}, {'text': 'beef', 'size': 11}, {'text': 'crab', 'size': 10}, {'text': 'stuffed', 'size': 9}, {'text': 'curry', 'size': 8}, {'text': 'garlic', 'size': 7}, {'text': 'salad', 'size': 6}, {'text': 'rice', 'size': 5}, {'text': 'indian', 'size': 4}, {'text': 'asian', 'size': 3}, {'text': 'coconut', 'size': 2}, {'text': 'stew', 'size': 1}])</script> </body>
# "
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Much better!

# %% [markdown]
# ## Where to next?
#
# Check out the other [Tutorials and Demos](../../../../doc/#builtin/Demos.md.html).
