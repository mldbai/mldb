# %% [markdown]
# # Identifying biased features
# This demo will show you how to identify features that help your models in a way that might just be too good to be true. At times it is hard to understand what a model is really doing, behind the scenes. That's where MLDB's [`classifier.explain`][1] comes to the rescue. In particular, it can help discover that a model is cheating, or in other words, that it has learnt to use bits of information that won't be available when applying the model in real life.
#
# To illustrate this, we are going to train a model on some data where we know a feature is biased. You can [find the details here][2]. Basically the task is to predict if the client will subscribe to a term deposit after he receives a call from the bank, given some informations about the client (the employee calling, scocioeconomic conditions at the time, etc.).
#
# [1]: ../../../../doc/#builtin/functions/ClassifierExplain.md.html
# [2]: http://archive.ics.uci.edu/ml/datasets/Bank+Marketing

# %%
import pymldb
mldb = pymldb.Connection()

# %% [markdown]
# Let's start by importing the data, which we have copied on our servers.

# %%
print mldb.put('/v1/procedures/_', {
    'type': 'import.text',
    'params': {
        'dataFileUrl':
            'archive+http://public.mldb.ai/datasets/bank-additional.zip#bank-additional/bank-additional-full.csv',
        'outputDataset': 'bank_raw',
        'delimiter': ';'
        }
    })
# Out:
# <Response [201]>

# %% [markdown]
# Here is a sneek peak of the data.

# %%
mldb.query("""
SELECT *
FROM bank_raw
LIMIT 10
""")
# Out:
#           age  campaign  "cons.conf.idx"  "cons.price.idx"    contact  \
# _rowName
# 2          56         1            -36.4            93.994  telephone
# 3          57         1            -36.4            93.994  telephone
# 4          37         1            -36.4            93.994  telephone
# 5          40         1            -36.4            93.994  telephone
# 6          56         1            -36.4            93.994  telephone
# 7          45         1            -36.4            93.994  telephone
# 8          59         1            -36.4            93.994  telephone
# 9          41         1            -36.4            93.994  telephone
# 10         24         1            -36.4            93.994  telephone
# 11         25         1            -36.4            93.994  telephone
#
#          day_of_week  default  duration            education  "emp.var.rate"  \
# _rowName
# 2                mon       no       261             basic.4y             1.1
# 3                mon  unknown       149          high.school             1.1
# 4                mon       no       226          high.school             1.1
# 5                mon       no       151             basic.6y             1.1
# 6                mon       no       307          high.school             1.1
# 7                mon  unknown       198             basic.9y             1.1
# 8                mon       no       139  professional.course             1.1
# 9                mon  unknown       217              unknown             1.1
# 10               mon       no       380  professional.course             1.1
# 11               mon       no        50          high.school             1.1
#
#          ...  housing          job loan  marital month "nr.employed"  pdays  \
# _rowName ...
# 2        ...       no    housemaid   no  married   may          5191    999
# 3        ...       no     services   no  married   may          5191    999
# 4        ...      yes     services   no  married   may          5191    999
# 5        ...       no       admin.   no  married   may          5191    999
# 6        ...       no     services  yes  married   may          5191    999
# 7        ...       no     services   no  married   may          5191    999
# 8        ...       no       admin.   no  married   may          5191    999
# 9        ...       no  blue-collar   no  married   may          5191    999
# 10       ...      yes   technician   no   single   may          5191    999
# 11       ...      yes     services   no   single   may          5191    999
#
#              poutcome previous   y
# _rowName
# 2         nonexistent        0  no
# 3         nonexistent        0  no
# 4         nonexistent        0  no
# 5         nonexistent        0  no
# 6         nonexistent        0  no
# 7         nonexistent        0  no
# 8         nonexistent        0  no
# 9         nonexistent        0  no
# 10        nonexistent        0  no
# 11        nonexistent        0  no
#
# [10 rows x 21 columns]

# %% [markdown]
# We can train a model on a random selection of 75% of the data, keeping the other 25% for testing.

# %%
print mldb.put('/v1/procedures/_', {
    'type': 'classifier.train',
    'params': {
        'trainingData': """
            SELECT features: {* EXCLUDING (y)}, label: y = 'yes'
            FROM bank_raw
            WHERE rowHash() % 4 != 0
            """,
        'modelFileUrl': 'file://bank_model.cls',
        'algorithm': 'bbdt',
        'functionName': 'score',
        'mode': 'boolean'
        }
    })
# Out:
# <Response [201]>

# %% [markdown]
# This creates a "score" function that we can use on examples from our test set. The higher the score, the more likely the client is going to subscribe.

# %%
mldb.query("""
SELECT score({features: {* EXCLUDING (y)}}) AS *
FROM bank_raw
WHERE rowHash() % 4 = 0
LIMIT 10
""")
# Out:
#              score
# _rowName
# 15       -2.730311
# 22       -7.071012
# 25       -3.583807
# 33       -2.070334
# 39        0.421762
# 40       -0.734294
# 47       -7.231209
# 62       -1.650849
# 63       -0.009851
# 65       -2.706054

# %% [markdown]
# Now let's test that model on the 25% we didn't train on and get a feel of how good it should perform in real life.

# %%
mldb.put('/v1/procedures/_', {
    'type': 'classifier.test',
    'params': {
        'testingData': """
            SELECT score: score({features: {* EXCLUDING (y)}})[score], label: y = 'yes'
            FROM bank_raw
            WHERE rowHash() % 4 = 0
            """,
        'outputDataset': 'bank_test',
        'mode': 'boolean'
        }
    })
# Out:
# <Response [201]>

# %% [markdown]
# As we can see by inspecting the different statistics returned by the classifier.test procedure, that model seems to be doing pretty good! The AUC is 0.95: let's ship this thing in production right now! ... Or let's be cautious!
#
# To understand what's going on, let's use the [`classifier.explain` function][1]. This will give us an idea of how much each feature helps (or hurts) in making the predictions.
#
# [1]: ../../../../doc/#builtin/functions/ClassifierExplain.md.html

# %%
print mldb.put('/v1/functions/explain', {
    'type': 'classifier.explain',
    'params': {
        'modelFileUrl': 'file://bank_model.cls'
        }
    })
# Out:
# <Response [201]>

# %% [markdown]
# You can "explain" every single example, and know how much each feature influence the final score, like this:

# %%
mldb.query("""
SELECT explain({features: {* EXCLUDING (y)}, label: y = 'yes'}) AS *
FROM bank_raw
WHERE rowHash() % 4 = 0
LIMIT 10
""")
# Out:
#               bias  explanation."""cons.conf.idx"""  \
# _rowName
# 15       -0.187552                         0.005895
# 22       -0.187552                         0.057059
# 25       -0.187552                         0.051206
# 33       -0.187552                         0.061675
# 39       -0.187552                         0.020152
# 40       -0.187552                         0.023699
# 47       -0.187552                         0.032773
# 62       -0.187552                         0.023699
# 63       -0.187552                        -0.021960
# 65       -0.187552                        -0.009339
#
#           explanation."""cons.price.idx"""  explanation."""emp.var.rate"""  \
# _rowName
# 15                                0.157162                        0.709004
# 22                                0.284745                        0.854344
# 25                                0.147233                        0.966030
# 33                                0.113903                        0.689183
# 39                                0.093249                        0.580062
# 40                                0.099499                        0.602229
# 47                                0.261927                        0.771801
# 62                                0.124415                        0.626461
# 63                                0.097264                        0.580062
# 65                                0.124415                        0.888562
#
#           explanation."""nr.employed"""  explanation.age  \
# _rowName
# 15                             0.357669         0.017939
# 22                             0.212641        -0.021539
# 25                             0.255613         0.136431
# 33                             0.348905        -0.154653
# 39                             0.199933        -0.058259
# 40                             0.278550         0.088830
# 47                             0.212641         0.128008
# 62                             0.293483         0.088830
# 63                             0.229247        -0.058259
# 65                             0.357669         0.090653
#
#           explanation.campaign  explanation.contact  explanation.day_of_week  \
# _rowName
# 15                    0.028919             0.083293                 0.025961
# 22                    0.008846             0.133029                 0.042484
# 25                    0.008406             0.083293                 0.030877
# 33                    0.028919             0.083293                 0.030877
# 39                    0.028919             0.102450                 0.030877
# 40                    0.030372             0.083293                 0.030877
# 47                    0.008846             0.083293                 0.030877
# 62                    0.030372             0.083293                 0.030877
# 63                    0.029360             0.126855                 0.011171
# 65                    0.029360             0.083293                 0.011171
#
#           explanation.default         ...           explanation.education  \
# _rowName                              ...
# 15                  -0.006558         ...                        0.054602
# 22                  -0.000070         ...                       -0.053114
# 25                  -0.006558         ...                       -0.037976
# 33                  -0.000070         ...                        0.114116
# 39                  -0.006558         ...                        0.027709
# 40                  -0.006558         ...                       -0.045472
# 47                   0.077405         ...                        0.013701
# 62                   0.077405         ...                       -0.045472
# 63                  -0.006558         ...                        0.029197
# 65                   0.077405         ...                        0.051012
#
#           explanation.euribor3m  explanation.job  explanation.loan  \
# _rowName
# 15                     0.259690         0.046422         -0.005966
# 22                     0.306672         0.059294         -0.005966
# 25                     0.363411        -0.020222         -0.005966
# 33                     0.231433        -0.023728         -0.005966
# 39                     0.118192        -0.009669         -0.021155
# 40                     0.134022         0.063472         -0.005966
# 47                     0.311449        -0.008973         -0.005966
# 62                     0.120093        -0.024413         -0.005966
# 63                     0.133764        -0.047023         -0.005966
# 65                     0.176531         0.031853         -0.005966
#
#           explanation.marital  explanation.month  explanation.pdays  \
# _rowName
# 15                   0.077895           0.308540           0.208543
# 22                  -0.007937           0.603028           0.208543
# 25                  -0.007937           0.415444           0.208543
# 33                   0.013465           0.303361           0.208543
# 39                  -0.007937           0.180797           0.208543
# 40                  -0.007937           0.253302           0.208543
# 47                  -0.007937           0.603620           0.208543
# 62                  -0.007937           0.293401           0.208543
# 63                  -0.004715           0.168900           0.208543
# 65                  -0.004715           0.256810           0.208543
#
#           explanation.poutcome  explanation.previous  explanation.housing
# _rowName
# 15                    0.031093             -0.010907                  NaN
# 22                    0.038117              0.007541            -0.061839
# 25                    0.038117             -0.010907                  NaN
# 33                    0.031093             -0.006298                  NaN
# 39                    0.031093             -0.009972                  NaN
# 40                    0.035534             -0.010907                  NaN
# 47                    0.038117             -0.009972            -0.061839
# 62                    0.035534             -0.010907                  NaN
# 63                    0.031093             -0.010907                  NaN
# 65                    0.031093             -0.010907                  NaN
#
# [10 rows x 21 columns]

# %% [markdown]
# Or you can do the average on all the examples. Here we then transpose the result and sort it by absolute value.

# %%
mldb.query("""
SELECT *
FROM transpose((
    SELECT avg({explain({features: {* EXCLUDING (y)}, label: y='yes'})[explanation] as *}) AS *
    NAMED 'explanation'
    FROM bank_raw
    WHERE rowHash() % 4 = 0
))
ORDER BY abs(explanation) DESC
""")
# Out:
#                       explanation
# _rowName
# duration                 1.297130
# """emp.var.rate"""       0.526305
# """nr.employed"""        0.303379
# pdays                    0.170738
# euribor3m                0.139221
# month                    0.135022
# """cons.price.idx"""     0.056744
# poutcome                 0.043148
# age                      0.035058
# """cons.conf.idx"""      0.020872
# job                      0.015212
# campaign                 0.013997
# default                  0.012997
# contact                  0.012676
# education                0.007162
# previous                -0.004830
# day_of_week              0.004189
# marital                  0.003695
# housing                  0.002859
# loan                     0.000629

# %% [markdown]
# Now what is striking here is that there is one feature that really stands out: duration. This is the actual duration of the call. Clearly, that information would not be available in a real life setting: you can't know the duration of a call before it's over, and when it's over you already now if the client has subscribed or not. If you look at the [detailed description of the data][1], you can in fact see a warning saying that using that piece of information is probably a bad idea for any realistic modeling.
#
# Now that we have identified the cause of those suspiciously good results, let's train and test again but ignoring it.
#
# [1]: http://archive.ics.uci.edu/ml/datasets/Bank+Marketing

# %%
print mldb.put('/v1/procedures/_', {
    'type': 'classifier.train',
    'params': {
        'trainingData': """
            SELECT features: {* EXCLUDING (y, duration)}, label: y = 'yes'
            FROM bank_raw
            WHERE rowHash() % 4 != 0
            """,
        'modelFileUrl': 'file://bank_model.cls',
        'algorithm': 'bbdt',
        'functionName': 'score',
        'mode': 'boolean'
        }
    })
# Out:
# <Response [201]>

# %%
mldb.put('/v1/procedures/_', {
    'type': 'classifier.test',
    'params': {
        'testingData': """
            SELECT score: score({features: {* EXCLUDING (y)}})[score], label: y = 'yes'
            FROM bank_raw
            WHERE rowHash() % 4 = 0
            """,
        'outputDataset': 'bank_test',
        'mode': 'boolean'
        }
    })
# Out:
# <Response [201]>

# %% [markdown]
# Now a AUC of 0.79 sounds more reasonable!
#
# If we run the explanation again, the highest ranking features seem more legitimate.

# %%
print mldb.put('/v1/functions/explain', {
    'type': 'classifier.explain',
    'params': {
        'modelFileUrl': 'file://bank_model.cls'
        }
    })
# Out:
# <Response [201]>

# %%
mldb.query("""
SELECT *
FROM transpose((
    SELECT avg({explain({features: {* EXCLUDING (y)}, label: y='yes'})[explanation] as *}) AS *
    NAMED 'explanation'
    FROM bank_raw
    WHERE rowHash() % 4 = 0
))
ORDER BY abs(explanation) DESC
""")
# Out:
#                       explanation
# _rowName
# """nr.employed"""        0.286326
# """emp.var.rate"""       0.245805
# pdays                    0.169785
# contact                  0.058398
# poutcome                 0.045957
# euribor3m                0.037370
# campaign                 0.019305
# month                    0.014595
# age                      0.010610
# job                      0.009837
# """cons.conf.idx"""      0.007304
# marital                  0.005593
# education                0.004860
# day_of_week              0.003192
# default                  0.002906
# """cons.price.idx"""     0.002791
# previous                -0.001921
# loan                     0.001670
# housing                  0.000537

# %% [markdown]
# ## Where to next?
#
# Check out the other [Tutorials and Demos](../../../../doc/#builtin/Demos.md.html).
