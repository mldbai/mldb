# %% [markdown]
# # SELECT Tutorial
#
#
# MLDB comes with a powerful [SQL-like Select Query](/doc/#builtin/sql/Sql.md.html) implementation accessible via its [REST API](/doc/#builtin/sql/QueryAPI.md.html). This tutorial will show a few different ways to query data.
#
# The notebook cells below use `pymldb`; you can check out the [Using `pymldb` Tutorial](/doc/nblink.html#_tutorials/Using pymldb Tutorial) for more details.

# %%
from pymldb import Connection
mldb = Connection()

# %% [markdown]
# # `SELECT`
#
# All queries start with the keyword `SELECT`. Here is the simplest possible query: we ask for 1 and we get a very short result set consisting of one row with one column named 1 and the single cell in it also contains 1.

# %%
mldb.query("""

select 1

""")
# Out:
#           1
# _rowName
#           1

# %% [markdown]
# Of course we can ask for more: the query below does a little math and shows how you can rename your columns with the `as` keyword. Note that single-quotes (`'`) are used to denote strings and double-quotes (`"`) denote column names, both of which can contain any Unicode character.

# %%
mldb.query("""

select 1+1, 3+4 as var, 'UTF8 striñg' as "hello, François"

""")
# Out:
#           1+1  var hello, François
# _rowName
#             2    7     UTF8 striñg

# %% [markdown]
# # `FROM` and `LIMIT`
#
# Queries are mostly useful when run on actual datasets, so let's import the passenger manifest from the Titanic.

# %%
print mldb.put('/v1/datasets/titanic', { 
    "type": "text.csv.tabular",
    "params": { 
        "dataFileUrl": "https://raw.githubusercontent.com/datacratic/mldb-pytanic-plugin/master/titanic_train.csv" 
    } 
})
# Out:
# <Response [201]>

# %% [markdown]
# Now let's query all columns with the star (`*`) operator `FROM` our `titanic` dataset, using the `LIMIT` keyword to avoid getting too much output.

# %%
mldb.query("""

select *
from titanic
limit 10

""")
# Out:
#           PassengerId  label  Pclass                            Name     Sex  \
# _rowName
# 97                 96      0       3         ShorneyMr.CharlesJoseph    male
# 273               272      1       3        TornquistMr.WilliamHenry    male
# 524               523      0       3                 LahoudMr.Sarkis    male
# 278               277      0       3   LindblomMiss.AugustaCharlotta  female
# 211               210      1       1                   BlankMr.Henry    male
# 210               209      1       3           CarrMiss.Helen"Ellen"  female
# 11                 10      1       2  NasserMrs.Nicholas(AdeleAchem)  female
# 281               280      1       3     AbbottMrs.Stanton(RosaHunt)  female
# 698               697      0       3                   KellyMr.James    male
# 460               459      1       2                ToomeyMiss.Ellen  female
#
#           Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# _rowName
# 97        NaN      0      0       374910   8.0500  None        S
# 273        25      0      0         LINE   0.0000  None        S
# 524       NaN      0      0         2624   7.2250  None        C
# 278        45      0      0       347073   7.7500  None        S
# 211        40      0      0       112277  31.0000   A31        C
# 210        16      0      0       367231   7.7500  None        Q
# 11         14      1      0       237736  30.0708  None        C
# 281        35      1      1     C.A.2673  20.2500  None        S
# 698        44      0      0       363592   8.0500  None        S
# 460        50      0      0  F.C.C.13531  10.5000  None        S

# %% [markdown]
# We can also ask for just certain columns by name.

# %%
mldb.query("""

select Name, Pclass
from titanic
limit 10
""")
# Out:
#                                     Name  Pclass
# _rowName
# 97               ShorneyMr.CharlesJoseph       3
# 273             TornquistMr.WilliamHenry       3
# 524                      LahoudMr.Sarkis       3
# 278        LindblomMiss.AugustaCharlotta       3
# 211                        BlankMr.Henry       1
# 210                CarrMiss.Helen"Ellen"       3
# 11        NasserMrs.Nicholas(AdeleAchem)       2
# 281          AbbottMrs.Stanton(RosaHunt)       3
# 698                        KellyMr.James       3
# 460                     ToomeyMiss.Ellen       2

# %% [markdown]
# # `ORDER BY`
#
# When we've used the `LIMIT` keyword above, it looked like we were just getting a random set of rows. Using the `ORDER BY` keyword we can ask for the 'top 10' according to some criterion.

# %%
mldb.query("""

select Name, Age
from titanic
order by Age desc 
limit 10

""")
# Out:
#                                      Name   Age
# _rowName
# 632       BarkworthMr.AlgernonHenryWilson  80.0
# 853                      SvenssonMr.Johan  74.0
# 98                  GoldschmidtMr.GeorgeB  71.0
# 495                  ArtagaveytiaMr.Ramon  71.0
# 118                     ConnorsMr.Patrick  70.5
# 674               MitchellMr.HenryMichael  70.0
# 747              CrosbyCapt.EdwardGifford  70.0
# 35                      WheadonMr.EdwardH  66.0
# 282                         DuaneMr.Frank  65.0
# 458                 MilletMr.FrancisDavis  65.0

# %% [markdown]
# # `WHERE`
#
# Beyond limiting the number of records, sometimes we want to look at records which match certain criteria, which we can do with the `WHERE` keyword.

# %%
mldb.query("""

select *
from titanic
where Pclass in (1,3) and Sex='male' and (SibSp=1 or Parch=1) and label=1 and Age is null

""")
# Out:
#           PassengerId  label  Pclass  \
# _rowName
# 711               710      1       3
# 67                 66      1       3
#
#                                                  Name   Sex   Age  SibSp  \
# _rowName
# 711       MoubarekMaster.HalimGonios("WilliamGeorge")  male  None      1
# 67                              MoubarekMaster.Gerios  male  None      1
#
#           Parch  Ticket     Fare Cabin Embarked
# _rowName
# 711           1    2661  15.2458  None        C
# 67            1    2661  15.2458  None        C

# %% [markdown]
# # Functions and Aggregate Functions
#
# MLDB comes with a number of builtin functions to operate on your data. Here's an example where we convert a string to uppercase and lowercase.

# %%
mldb.query("""

select Name, upper(Name), lower(Name)
from titanic
order by Age desc limit 10

""")
# Out:
#                                      Name                      upper(Name)  \
# _rowName
# 632       BarkworthMr.AlgernonHenryWilson  BARKWORTHMR.ALGERNONHENRYWILSON
# 853                      SvenssonMr.Johan                 SVENSSONMR.JOHAN
# 98                  GoldschmidtMr.GeorgeB            GOLDSCHMIDTMR.GEORGEB
# 495                  ArtagaveytiaMr.Ramon             ARTAGAVEYTIAMR.RAMON
# 118                     ConnorsMr.Patrick                CONNORSMR.PATRICK
# 674               MitchellMr.HenryMichael          MITCHELLMR.HENRYMICHAEL
# 747              CrosbyCapt.EdwardGifford         CROSBYCAPT.EDWARDGIFFORD
# 35                      WheadonMr.EdwardH                WHEADONMR.EDWARDH
# 282                         DuaneMr.Frank                    DUANEMR.FRANK
# 458                 MilletMr.FrancisDavis            MILLETMR.FRANCISDAVIS
#
#                               lower(Name)
# _rowName
# 632       barkworthmr.algernonhenrywilson
# 853                      svenssonmr.johan
# 98                  goldschmidtmr.georgeb
# 495                  artagaveytiamr.ramon
# 118                     connorsmr.patrick
# 674               mitchellmr.henrymichael
# 747              crosbycapt.edwardgifford
# 35                      wheadonmr.edwardh
# 282                         duanemr.frank
# 458                 milletmr.francisdavis

# %% [markdown]
# The `avg()` function below is a special kind of function: it's an aggregate function, so it operates on multiple rows and gives you a single output.

# %%
mldb.query("""

select avg(Age)
from titanic

""")
# Out:
#            avg(Age)
# _rowName
# []        29.699118

# %% [markdown]
# # GROUP BY & HAVING
#
# You can get aggregate functions to return multiple rows by grouping the input according to some criteria with the `GROUP BY` keyword

# %%
mldb.query("""

select Pclass, avg(Age)
from titanic
group by Pclass

""")
# Out:
#           Pclass   avg(Age)
# _rowName
# [1]            1  38.233441
# [2]            2  29.877630
# [3]            3  25.140620

# %% [markdown]
# The `count()` aggregate function is one of the most useful functions and it's a little special: it counts the number of non-null elements in its input. It can also take a star (`*`) to count all rows in its input.

# %%
mldb.query("""

select Pclass, count(Age), count(*)
from titanic
group by Pclass

""")
# Out:
#           Pclass  count(Age)  count(*)
# _rowName
# [1]            1         186       216
# [2]            2         173       184
# [3]            3         355       491

# %% [markdown]
# The `HAVING` clause is a little bit like a `WHERE` clause which is applied after `GROUP BY`.

# %%
mldb.query("""

select Pclass, avg(Age)
from titanic
group by Pclass
having avg(Age) > 30

""")
# Out:
#           Pclass   avg(Age)
# _rowName
# [1]            1  38.233441

# %% [markdown]
# # Advanced `FROM` with subqueries

# %% [markdown]
# You can get a similar effect to the `HAVING` clause (for a performance hit) by using a second query within your `FROM` clause:

# %%
mldb.query("""

select *
from (
    select Pclass, avg(Age) as mean_age
    from titanic
    group by Pclass
)
where mean_age > 30

""")
# Out:
#           Pclass   mean_age
# _rowName
# [1]            1  38.233441

# %% [markdown]
# # `INTO`: supported via `transform` Procedures
#
# Other databases support an `INTO` keyword to create new datasets from the output of queries. MLDB does not support this, so as to make `SELECT` queries idempotent, but you can accomplish the same task with a `transform` procedure.

# %%
not_supported = """
    select Pclass, avg(Age) as mean_age
    into class_stats
    from titanic
    group by Pclass
"""

supported = mldb.post('/v1/procedures', { 
    "type": "transform",
    "params": { 
        "inputData": """
                select Pclass, avg(Age) as mean_age
                from titanic
                group by Pclass
        """,
        "outputDataset": "class_stats",
        "runOnCreation": True
    } 
})

print supported
# Out:
# <Response [201]>

# %% [markdown]
# We can now query our new table!

# %%
mldb.query("""

select *
from class_stats

""")
# Out:
#           Pclass   mean_age
# _rowName
# [1]            1  38.233441
# [3]            3  25.140620
# [2]            2  29.877630

# %% [markdown]
# # Advanced `FROM` with `JOIN`
#
# You can run queries across multiple tables with the `JOIN` keyword.

# %%
mldb.query("""

select titanic.Name, titanic.Pclass, class_stats.*
from 
    titanic JOIN class_stats 
        ON titanic.Pclass = class_stats.Pclass    
    
order by Age desc limit 10

""")
# Out:
#                                            titanic.Name  titanic.Pclass  \
# _rowName
# [835]-[[3]]                         AugustssonMr.Albert               3
# [60]-[[2]]                     WestMiss.ConstanceMirium               2
# [78]-[[3]]                               StaneffMr.Ivan               3
# [356]-[[3]]                              YousifMr.Wazli               3
# [134]-[[3]]     RobinsMrs.AlexanderA(GraceCharityLaury)               3
# [740]-[[3]]                             IvanoffMr.Kanio               3
# [652]-[[3]]                              MitkoffMr.Mito               3
# [10]-[[3]]   JohnsonMrs.OscarW(ElisabethVilhelminaBerg)               3
# [249]-[[2]]                 HamalainenMrs.William(Anna)               2
# [280]-[[3]]                             RiceMaster.Eric               3
#
#              class_stats.Pclass  class_stats.mean_age
# _rowName
# [835]-[[3]]                   3              25.14062
# [60]-[[2]]                    2              29.87763
# [78]-[[3]]                    3              25.14062
# [356]-[[3]]                   3              25.14062
# [134]-[[3]]                   3              25.14062
# [740]-[[3]]                   3              25.14062
# [652]-[[3]]                   3              25.14062
# [10]-[[3]]                    3              25.14062
# [249]-[[2]]                   2              29.87763
# [280]-[[3]]                   3              25.14062

# %% [markdown]
# ----------

# %% [markdown]
# # MLDB extensions to conventional SQL

# %% [markdown]
# Selecting columns based on a prefix.

# %%
mldb.query("""

select P*
from titanic
limit 1

""")
# Out:
#           PassengerId  Pclass  Parch
# _rowName
# 97                 96       3      0

# %% [markdown]
# Renaming columns based on a prefix pattern

# %%
mldb.query("""

select P* as x*
from titanic
limit 1

""")
# Out:
#           xassengerId  xclass  xarch
# _rowName
# 97                 96       3      0

# %% [markdown]
# Excluding columns from a select.

# %%
mldb.query("""

select * excluding(P*)
from titanic
limit 1

""")
# Out:
#           label                     Name   Sex   Age  SibSp  Ticket  Fare  \
# _rowName
# 97            0  ShorneyMr.CharlesJoseph  male  None      0  374910  8.05
#
#          Cabin Embarked
# _rowName
# 97        None        S

# %% [markdown]
# NOTE: Selecting a column which is not in the dataset will not cause an error, but it will return `NULL`.

# %%
mldb.query("""

select nothing
from titanic
limit 1

""")
# Out:
#          nothing
# _rowName
# 97          None

# %% [markdown]
# MLDB supports JSON-like objects in queries.

# %%
mldb.query("""

select {a: 1, b:2, c: 'hello'}

""")
# Out:
#           {a: 1, b:2, c: 'hello'}.a  {a: 1, b:2, c: 'hello'}.b  \
# _rowName
#                                   1                          2
#
#          {a: 1, b:2, c: 'hello'}.c
# _rowName
#                              hello

# %%
mldb.query("""

select {a: 1, b:2, c: 'hello'} as obj

""")
# Out:
#           obj.a  obj.b  obj.c
# _rowName
#               1      2  hello

# %%
mldb.query("""

select {a: 1, b:{x:2}, c: 'hello'} as *

""")
# Out:
#           a  b.x      c
# _rowName
#           1    2  hello

# %% [markdown]
# This is especially useful for tokenizing text into bags of words, or importing semi-structured JSON data.

# %%
mldb.query("""

select tokenize('Hello world, Hello!', {splitchars: ' ,!'}) as *

""")
# Out:
#           world  Hello
# _rowName
#               1      2

# %%
mldb.query("""

select parse_json('{"hello":"world","list":[1,2,3,4]}') as *

""")
# Out:
#           hello  list.0  list.1  list.2  list.3
# _rowName
#           world       1       2       3       4

# %% [markdown]
# MLDB's object notation also allows you to run aggregates on multiple columns at once.

# %%
mldb.query("""

select Pclass, count(*), count({*})
from titanic
group by Pclass

""")
# Out:
#           Pclass  count(*)  count({*}).Age  count({*}).Cabin  \
# _rowName
# [1]            1       216             186               176
# [2]            2       184             173                16
# [3]            3       491             355                12
#
#           count({*}).Embarked  count({*}).Fare  count({*}).Name  \
# _rowName
# [1]                       214              216              216
# [2]                       184              184              184
# [3]                       491              491              491
#
#           count({*}).Parch  count({*}).PassengerId  count({*}).Pclass  \
# _rowName
# [1]                    216                     216                216
# [2]                    184                     184                184
# [3]                    491                     491                491
#
#           count({*}).Sex  count({*}).SibSp  count({*}).Ticket  \
# _rowName
# [1]                  216               216                216
# [2]                  184               184                184
# [3]                  491               491                491
#
#           count({*}).label
# _rowName
# [1]                    216
# [2]                    184
# [3]                    491

# %% [markdown]
# MLDB's flexible output model enables powerful functions like `pivot()` to exist.

# %%
mldb.query("""

select Pclass, pivot(Sex, "count(*)") as *
from (
    select Pclass, Sex, count(*)
    from titanic
    group by Pclass, Sex
)
group by Pclass

""")
# Out:
#           Pclass  female  male
# _rowName
# [1]            1      94   122
# [2]            2      76   108
# [3]            3     144   347

# %% [markdown]
# MLDB supports multi-dimensional arrays called embeddings, also known as tensors.

# %%
mldb.query("""

select [1,2,3] as embedding

""")
# Out:
#           embedding.0  embedding.1  embedding.2
# _rowName
#                     1            2            3

# %%
mldb.query("""

select normalize([1,2,3], 1) as n,  [1,2,3] / norm([1,2,3] ,1) as d

""")
# Out:
#                n.0       n.1  n.2       d.0       d.1  d.2
# _rowName
#           0.166667  0.333333  0.5  0.166667  0.333333  0.5

# %% [markdown]
# MLDB datasets have named rows as well as columns, and the `NAMED` keyword allows you to control the names of your output rows.

# %%
mldb.query("""

select *
named Name + ' aged ' + cast(Age as string)
from titanic
order by Age desc limit 10

""")
# Out:
#                                         PassengerId  label  Pclass  \
# _rowName
# ShorneyMr.CharlesJoseph aged                     96      0       3
# TornquistMr.WilliamHenry aged 25                272      1       3
# LahoudMr.Sarkis aged                            523      0       3
# LindblomMiss.AugustaCharlotta aged 45           277      0       3
# BlankMr.Henry aged 40                           210      1       1
# CarrMiss.Helen"Ellen" aged 16                   209      1       3
# NasserMrs.Nicholas(AdeleAchem) aged 14           10      1       2
# AbbottMrs.Stanton(RosaHunt) aged 35             280      1       3
# KellyMr.James aged 44                           697      0       3
# ToomeyMiss.Ellen aged 50                        459      1       2
#
#                                                                   Name  \
# _rowName
# ShorneyMr.CharlesJoseph aged                   ShorneyMr.CharlesJoseph
# TornquistMr.WilliamHenry aged 25              TornquistMr.WilliamHenry
# LahoudMr.Sarkis aged                                   LahoudMr.Sarkis
# LindblomMiss.AugustaCharlotta aged 45    LindblomMiss.AugustaCharlotta
# BlankMr.Henry aged 40                                    BlankMr.Henry
# CarrMiss.Helen"Ellen" aged 16                    CarrMiss.Helen"Ellen"
# NasserMrs.Nicholas(AdeleAchem) aged 14  NasserMrs.Nicholas(AdeleAchem)
# AbbottMrs.Stanton(RosaHunt) aged 35        AbbottMrs.Stanton(RosaHunt)
# KellyMr.James aged 44                                    KellyMr.James
# ToomeyMiss.Ellen aged 50                              ToomeyMiss.Ellen
#
#                                            Sex  Age  SibSp  Parch  \
# _rowName
# ShorneyMr.CharlesJoseph aged              male  NaN      0      0
# TornquistMr.WilliamHenry aged 25          male   25      0      0
# LahoudMr.Sarkis aged                      male  NaN      0      0
# LindblomMiss.AugustaCharlotta aged 45   female   45      0      0
# BlankMr.Henry aged 40                     male   40      0      0
# CarrMiss.Helen"Ellen" aged 16           female   16      0      0
# NasserMrs.Nicholas(AdeleAchem) aged 14  female   14      1      0
# AbbottMrs.Stanton(RosaHunt) aged 35     female   35      1      1
# KellyMr.James aged 44                     male   44      0      0
# ToomeyMiss.Ellen aged 50                female   50      0      0
#
#                                              Ticket     Fare Cabin Embarked
# _rowName
# ShorneyMr.CharlesJoseph aged                 374910   8.0500  None        S
# TornquistMr.WilliamHenry aged 25               LINE   0.0000  None        S
# LahoudMr.Sarkis aged                           2624   7.2250  None        C
# LindblomMiss.AugustaCharlotta aged 45        347073   7.7500  None        S
# BlankMr.Henry aged 40                        112277  31.0000   A31        C
# CarrMiss.Helen"Ellen" aged 16                367231   7.7500  None        Q
# NasserMrs.Nicholas(AdeleAchem) aged 14       237736  30.0708  None        C
# AbbottMrs.Stanton(RosaHunt) aged 35        C.A.2673  20.2500  None        S
# KellyMr.James aged 44                        363592   8.0500  None        S
# ToomeyMiss.Ellen aged 50                F.C.C.13531  10.5000  None        S

# %% [markdown]
# Having named rows as well as columns allows us to easily operate on the transpose of a dataset

# %%
mldb.query("""

select * from transpose(
    (
        select *
        named Name + ' aged ' + cast(Age as string)
        from titanic
        order by Age desc limit 10
    ) as original
)

""")
# Out:
#             ShorneyMr.CharlesJoseph aged  TornquistMr.WilliamHenry aged 25  \
# _rowName
# Cabin                                None                             None
# Fare                                 8.05                                0
# SibSp                                   0                                0
# Ticket                             374910                             LINE
# PassengerId                            96                              272
# label                                   0                                1
# Age                                  None                               25
# Pclass                                  3                                3
# Name              ShorneyMr.CharlesJoseph         TornquistMr.WilliamHenry
# Sex                                  male                             male
# Parch                                   0                                0
# Embarked                                S                                S
#
#             LahoudMr.Sarkis aged  LindblomMiss.AugustaCharlotta aged 45  \
# _rowName
# Cabin                        None                                  None
# Fare                        7.225                                  7.75
# SibSp                           0                                     0
# Ticket                       2624                                347073
# PassengerId                   523                                   277
# label                           0                                     0
# Age                          None                                    45
# Pclass                          3                                     3
# Name              LahoudMr.Sarkis         LindblomMiss.AugustaCharlotta
# Sex                          male                                female
# Parch                           0                                     0
# Embarked                        C                                     S
#
#             BlankMr.Henry aged 40 CarrMiss.Helen"Ellen" aged 16  \
# _rowName
# Cabin                         A31                          None
# Fare                           31                          7.75
# SibSp                           0                             0
# Ticket                     112277                        367231
# PassengerId                   210                           209
# label                           1                             1
# Age                            40                            16
# Pclass                          1                             3
# Name                BlankMr.Henry         CarrMiss.Helen"Ellen"
# Sex                          male                        female
# Parch                           0                             0
# Embarked                        C                             Q
#
#             NasserMrs.Nicholas(AdeleAchem) aged 14  \
# _rowName
# Cabin                                         None
# Fare                                       30.0708
# SibSp                                            1
# Ticket                                      237736
# PassengerId                                     10
# label                                            1
# Age                                             14
# Pclass                                           2
# Name                NasserMrs.Nicholas(AdeleAchem)
# Sex                                         female
# Parch                                            0
# Embarked                                         C
#
#             AbbottMrs.Stanton(RosaHunt) aged 35 KellyMr.James aged 44  \
# _rowName
# Cabin                                      None                  None
# Fare                                      20.25                  8.05
# SibSp                                         1                     0
# Ticket                                 C.A.2673                363592
# PassengerId                                 280                   697
# label                                         1                     0
# Age                                          35                    44
# Pclass                                        3                     3
# Name                AbbottMrs.Stanton(RosaHunt)         KellyMr.James
# Sex                                      female                  male
# Parch                                         1                     0
# Embarked                                      S                     S
#
#             ToomeyMiss.Ellen aged 50
# _rowName
# Cabin                           None
# Fare                            10.5
# SibSp                              0
# Ticket                   F.C.C.13531
# PassengerId                      459
# label                              1
# Age                               50
# Pclass                             2
# Name                ToomeyMiss.Ellen
# Sex                           female
# Parch                              0
# Embarked                           S

# %% [markdown]
# MLDB supports inline Javascript application via the `jseval()` function.

# %%
mldb.query("""

select Name,
    jseval('
        return Name.replace(/([A-Z])/g, function(m, p) { return " "+p; });
    ', 'Name', Name) as processed_name
from titanic
order by Age desc limit 10

""")
# Out:
#                                     Name                       processed_name
# _rowName
# 97               ShorneyMr.CharlesJoseph           Shorney Mr. Charles Joseph
# 273             TornquistMr.WilliamHenry          Tornquist Mr. William Henry
# 524                      LahoudMr.Sarkis                    Lahoud Mr. Sarkis
# 278        LindblomMiss.AugustaCharlotta     Lindblom Miss. Augusta Charlotta
# 211                        BlankMr.Henry                      Blank Mr. Henry
# 210                CarrMiss.Helen"Ellen"             Carr Miss. Helen" Ellen"
# 11        NasserMrs.Nicholas(AdeleAchem)   Nasser Mrs. Nicholas( Adele Achem)
# 281          AbbottMrs.Stanton(RosaHunt)      Abbott Mrs. Stanton( Rosa Hunt)
# 698                        KellyMr.James                      Kelly Mr. James
# 460                     ToomeyMiss.Ellen                   Toomey Miss. Ellen

# %% [markdown]
# MLDB datasets handle millions of columns, and deal very well with sparse datasets, making them ideal for operating on bags of words.

# %%
mldb.query("""

select tokenize(
    jseval('
        return Name.replace(/([A-Z])/g, function(m, p) { return " "+p; });
    ', 'Name', Name),
    {splitchars: ' .()"', quotechar:''}) as *
from titanic
order by Age desc
limit 10

""")
# Out:
#           Henry  Algernon  Mr  Wilson  Barkworth  Johan  Svensson   B  George  \
# _rowName
# 632           1         1   1       1          1    NaN       NaN NaN     NaN
# 853         NaN       NaN   1     NaN        NaN      1         1 NaN     NaN
# 98          NaN       NaN   1     NaN        NaN    NaN       NaN   1       1
# 495         NaN       NaN   1     NaN        NaN    NaN       NaN NaN     NaN
# 118         NaN       NaN   1     NaN        NaN    NaN       NaN NaN     NaN
# 674           1       NaN   1     NaN        NaN    NaN       NaN NaN     NaN
# 747         NaN       NaN NaN     NaN        NaN    NaN       NaN NaN     NaN
# 35          NaN       NaN   1     NaN        NaN    NaN       NaN NaN     NaN
# 282         NaN       NaN   1     NaN        NaN    NaN       NaN NaN     NaN
# 458         NaN       NaN   1     NaN        NaN    NaN       NaN NaN     NaN
#
#           Goldschmidt   ...    Edward  Capt  Crosby   H  Wheadon  Frank  \
# _rowName                ...
# 632               NaN   ...       NaN   NaN     NaN NaN      NaN    NaN
# 853               NaN   ...       NaN   NaN     NaN NaN      NaN    NaN
# 98                  1   ...       NaN   NaN     NaN NaN      NaN    NaN
# 495               NaN   ...       NaN   NaN     NaN NaN      NaN    NaN
# 118               NaN   ...       NaN   NaN     NaN NaN      NaN    NaN
# 674               NaN   ...       NaN   NaN     NaN NaN      NaN    NaN
# 747               NaN   ...         1     1       1 NaN      NaN    NaN
# 35                NaN   ...         1   NaN     NaN   1        1    NaN
# 282               NaN   ...       NaN   NaN     NaN NaN      NaN      1
# 458               NaN   ...       NaN   NaN     NaN NaN      NaN    NaN
#
#           Duane  Davis  Francis  Millet
# _rowName
# 632         NaN    NaN      NaN     NaN
# 853         NaN    NaN      NaN     NaN
# 98          NaN    NaN      NaN     NaN
# 495         NaN    NaN      NaN     NaN
# 118         NaN    NaN      NaN     NaN
# 674         NaN    NaN      NaN     NaN
# 747         NaN    NaN      NaN     NaN
# 35          NaN    NaN      NaN     NaN
# 282           1    NaN      NaN     NaN
# 458         NaN      1        1       1
#
# [10 rows x 27 columns]

# %% [markdown]
# Putting it all together, here are the top 20 tokens present in the names of Titanic passengers.

# %%
mldb.query("""

select * from transpose(
    (
        select sum(
            tokenize(
                jseval('
                    return Name.replace(/([A-Z])/g, function(m, p) { return " "+p; });
                ', 'Name', Name),
                {splitchars: ' .()"', quotechar:''})
            ) as *
        named 'counts'
        from titanic
    )
)
order by counts desc limit 20

""")
# Out:
#            counts
# _rowName
# Mr            521
# Miss          182
# Mrs           128
# William        64
# John           44
# Master         40
# Henry          35
# George         24
# James          24
# Charles        24
# Thomas         22
# Mary           20
# Edward         18
# Anna           17
# Joseph         16
# Frederick      15
# Johan          15
# Elizabeth      15
# Richard        14
# Samuel         13

# %% [markdown]
# ## Where to next?
#
# Check out the other [Tutorials and Demos](/doc/#builtin/Demos.md.html).
